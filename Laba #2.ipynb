# %% [markdown]
# (Дополнительное задание) Имеется структура данных cook_book, в которой хранится информация об ингредиентах блюд и их количестве в расчете на одну порцию и переменная, в которой хранится количество людей, на которых необходимо приготовить данные блюда:

# %%
cook_book = [
  ['салат',
      [
        ['картофель', 100, 'гр.'],
        ['морковь', 50, 'гр.'],
        ['огурцы', 50, 'гр.'],
        ['горошек', 30, 'гр.'],
        ['майонез', 70, 'мл.'],
      ]
  ],
  ['пицца',  
      [
        ['сыр', 50, 'гр.'],
        ['томаты', 50, 'гр.'],
        ['тесто', 100, 'гр.'],
        ['бекон', 30, 'гр.'],
        ['колбаса', 30, 'гр.'],
        ['грибы', 20, 'гр.'],
      ],
  ],
  ['фруктовый десерт',
      [
        ['хурма', 60, 'гр.'],
        ['киви', 60, 'гр.'],
        ['творог', 60, 'гр.'],
        ['сахар', 10, 'гр.'],
        ['мед', 50, 'мл.'],  
      ]
  ]
]

person = int(input()) #Количество персон

# %% [markdown]
# in: 5
# out:
# Салат:
# картофель, 500гр.
# морковь, 250гр.
# огурцы, 250гр.
# горошек, 150гр.
# майонез, 350мл.
#
# Пицца:
# сыр, 250гр.
# томаты, 250гр.
# тесто, 500гр.
# бекон, 150гр.
# колбаса, 150гр.
# грибы, 100гр.
#
# Фруктовый десерт:
# хурма, 300гр.
# киви, 300гр.
# творог, 300гр.
# сахар, 50гр.
# мед, 250мл.

# %%
#Код пишите здесь

# %% [markdown]
# ## Задание #1
# ### 1.1. Создать массив, где количество элементов будет генерироваться случайным образом от 5 до 15 и элементами будут являться случайные целочисленные элементы от 0 до 50

# %% [markdown]
# ### 1.2. Написать функцию для выборки четырех случайных элементов из массива и вывода их на экран

# %% [markdown]
# ### 1.3. Написать функцию, которая ищет минимальный и максимальный элемент массива, вывести эти значения и индексы в массиве

# %% [markdown]
# ### 1.4. Протестировать функции из заданий 3 и 2, передавая туда несколько разных массивов со случайными значениями

# %% [markdown]
# ## Задание #2
#
# ### 2.1. Создать множество из 10 элементов, добавить в него 3 элемента, с помощью add и удалить последний элемент из множества

# %% [markdown]
# ### 2.2. Напишите программу для вывода количества уникальных символов каждого считанного слова без учета регистра.
#
# in 1: \
# Введите количество слов: 3 \
# Тимур \
# Beegeek \
# АнанАс \
# out 1: \
# 5 \
# 4 \
# 3 \
# \
# in 2: \
# Введите количество слов: 5 \
# абОнемЕнТы \
# дозировка \
# военкОмат \
# ДрУжиНник \
# ОпПозицИя \
# out 2: \
# 8 \
# 8 \
# 8 \
# 7 \
# 6

# %% [markdown]
# ### 2.3. Преобразовать множество в список (массив)

# %% [markdown]
# ### 2.4. Дополните приведенный код, чтобы он вывел элементы множества fruits, каждый на отдельной строке, отсортированные по убыванию (в обратном лексикографическом порядке).

# %%
fruits = {'apple', 'banana', 'cherry', 'avocado', 'pineapple', 'apricot', 'banana', 'avocado', 'grapefruit'}

# %% [markdown]
# ### 2.5. На вход программе подается строка текста. Напишите программу, которая определяет количество различных символов в строке.
#
# in 1: \
# 12345678910 \
# out 1: \
# 10 \
#  \
# in 2: \
# ab bc \
# out 2: \
# 4

# %% [markdown]
# ## Задание #3
# ### 3.1. Напишите алгоритм, который выводит имена всех пользователей, чей номер оканчивается на 8.

# %%
users = [{'name': 'Todd', 'phone': '551-1414', 'email': 'todd@gmail.com'},
         {'name': 'Helga', 'phone': '555-1618', 'email': 'helga@mail.net'},
         {'name': 'Olivia', 'phone': '449-3141', 'email': ''},
         {'name': 'LJ', 'phone': '555-2718', 'email': 'lj@gmail.net'},
         {'name': 'Ruslan', 'phone': '422-145-9098', 'email': 'rus-lan.cha@yandex.ru'},
         {'name': 'John', 'phone': '233-421-32', 'email': ''},
         {'name': 'Lara', 'phone': '+7998-676-2532', 'email': 'g.lara89@gmail.com'},
         {'name': 'Alina', 'phone': '+7948-799-2434', 'email': 'ali.ch.b@gmail.com'},
         {'name': 'Robert', 'phone': '420-2011', 'email': ''},
         {'name': 'Riyad', 'phone': '128-8890-128', 'email': 'r.mahrez@mail.net'},
         {'name': 'Khabib', 'phone': '+7995-600-9080', 'email': 'kh.nurmag@gmail.com'},
         {'name': 'Olga', 'phone': '6449-314-1213', 'email': ''},
         {'name': 'Roman', 'phone': '+7459-145-8059', 'email': 'roma988@mail.ru'},
         {'name': 'Maria', 'phone': '12-129-3148', 'email': 'm.sharapova@gmail.com'},
         {'name': 'Fedor', 'phone': '+7445-341-0545', 'email': ''},
         {'name': 'Tim', 'phone': '242-449-3141', 'email': 'timm.ggg@yandex.ru'}]

#Код писать здесь

# %% [markdown]
# ### 3.2. Напишите программу, которая по номеру дисциплины выводит информацию о данном курсе.
#
# Номер дисциплины(ключ) Название дисциплины(значение)  Номер аудитории (значение)   Преподаватель (значение)  Время (значение) \
# CS101	               Программирование                 3004	                Хайнс                 8:00 \
# CS102                   Анализ данных                  4501	                  Альварадо	              9:00 \
# CS103	                Веб-разработка                  6755	                 Рич	             10:00 \
# NT110	                  Графика                     1244	                   Берк                 11:00 \
# CM241	                    ИБ                       1411	                  Ли                  13:00
#
# #### Необходимо сформировать словарь и написать алгоритм вывода

# %% [markdown]
# ### 3.3. На вход программе подается список стран и городов каждой страны. Затем даны названия городов. Напишите программу, которая для каждого города выводит, в какой стране он находится.
#
# #### Формат входных данных
# Программа получает на вход количество стран nn. Далее идет nn строк, каждая строка начинается с названия страны, затем идут названия городов этой страны. В следующей строке записано число mm, далее идут mm запросов — названия каких-то mm городов, из перечисленных выше.
#
# #### Формат выходных данных
# Программа должна вывести название страны, в которой находится данный город в соответствии с примером.
#
# in 1:
# #### Введите количество стран: 2
# Германия Берлин Мюнхен Гамбург Дортмунд \
# Нидерланды Амстердам Гаага Роттердам Алкмар
# #### Введите количество городов: 4
# Амстердам \
# Алкмар \
# Гамбург \
# Гаага \
# \
# Sample Output: \
# \
# Нидерланды \
# Нидерланды \
# Германия \
# Нидерланды
